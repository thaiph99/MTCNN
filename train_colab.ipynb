# %% [markdown]
# <a href="https://colab.research.google.com/github/thaiph99/MTCNN/blob/main/train_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount google drive
from google.colab import drive
drive.mount( '/content/gdrive' )
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# cd path
import os
root = '/content/gdrive/Shareddrives/storage/mtcnn-tf-plate-detection'
os.chdir(root)
# !pwd
# Out:
# /content/gdrive/Shareddrives/storage/mtcnn-tf-plate-detection

# %%
# !pip install -r requirements.txt

# %%
# !nvidia-smi
# Out:
# Sat Jan 15 14:34:18 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !sh clearAll.sh
# Out:
# clear all: rm -r ./tmp
# Done!

# %%
# !sh runAll.sh
# Out:
# Hello! I will prepare training data and starting to training step by step.
# Checking dataset pass.
# Preparing P-Net training data: bbox
# >>>>>> Gen hard samples for pnet...
# height 1385 width 1024 channel 3
#
# [1] pos: 6  neg: 55  part:14height 1432 width 1024 channel 3
#
# [2] pos: 13  neg: 108  part:27height 768 width 1024 channel 3
#
# [3] pos: 13  neg: 158  part:27height 682 width 1024 channel 3
#
# [4] pos: 42  neg: 236  part:134height 852 width 1024 channel 3
#
# [5] pos: 62  neg: 301  part:174height 931 width 1024 channel 3
#
# [6] pos: 62  neg: 351  part:174height 732 width 1024 channel 3
#
# [7] pos: 73  neg: 406  part:183height 683 width 1024 channel 3
#
# [8] pos: 134  neg: 502  part:342height 819 width 1024 channel 3
#
# [9] pos: 153  neg: 575  part:479height 768 width 1024 channel 3
#
# [10] pos: 182  neg: 642  part:530height 755 width 1024 channel 3
#
# [11] pos: 218  neg: 721  part:614height 863 width 1024 channel 3
#
# ...
